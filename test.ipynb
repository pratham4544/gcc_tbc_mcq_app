# %%
print('Working Fine...')
# Out:
# Working Fine...

# %%
from PyPDF2 import PdfReader

# Read the PDF file
reader = PdfReader('101ENG_30.pdf')
all_text = ""

# Extract text from each page
for page in reader.pages:
    all_text += page.extract_text()

print(all_text)
# Out:
# Sr.No  Question  Option A  Option B  Option C  Option D
# Provision
# al Answer
# 1 What is PPT?PowerPoi
# nt Page
# PresentatiProper
# PresentatiNone of
# these A
# 2 BMP means _______________Bitmap
# PageBitmap
# ImageBitwise
# ImageBitmap
# Picture B
# 3You cannot view Ruler in
# PowerPoint. TRUE FALSE B
# 4We can provide date and time to
# slides TRUE FALSE A
# 5How can you see all your chart at
# once?through
# slide viewthrough
# reading
# viewthrough
# slide
# sorter through
# normal
# view C
# 6In E-Mail address separate the name
# and the domain with an "@" symbol. TRUE FALSE A
# 7________________ allows the
# clients to share its resources Server Client ModemNone of
# these A
# 8_________ Is a special function key
# available on the keyboard. Pause Tab Esc F10 D
# 9 How can Email be sorted?In order of
# the time
# receivedIn order
# by the
# name of In order
# by date
# receivedAll of
# these B
# 10Internet Explore is one of the best
# example of Output Device TRUE FALSE B
# ...
